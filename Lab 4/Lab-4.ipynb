# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age',
'label']
df = pd.read_csv("diabetes.csv", header=None, skiprows=1, names=col_names);
df.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
X = df.iloc[:,0:-1]
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 40)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6926406926406926

# %% [markdown]
# <h1>Visualizing Decision Tree</h1>

# %%
from sklearn.tree import plot_tree
from matplotlib.pylab import rcParams

# %%
rcParams['figure.figsize'] = 80, 50
plot_tree(clf)
# Out:
# [Text(0.41259765625, 0.9642857142857143, 'x[1] <= 127.5\ngini = 0.444\nsamples = 537\nvalue = [358, 179]'),
#  Text(0.18359375, 0.8928571428571429, 'x[7] <= 28.5\ngini = 0.306\nsamples = 339\nvalue = [275, 64]'),
#  Text(0.125, 0.8214285714285714, 'x[5] <= 50.15\ngini = 0.135\nsamples = 193\nvalue = [179.0, 14.0]'),
#  Text(0.11458333333333333, 0.75, 'x[0] <= 7.5\ngini = 0.126\nsamples = 192\nvalue = [179, 13]'),
#  Text(0.10416666666666667, 0.6785714285714286, 'x[5] <= 30.95\ngini = 0.118\nsamples = 191\nvalue = [179, 12]'),
#  Text(0.08333333333333333, 0.6071428571428571, 'x[6] <= 0.672\ngini = 0.018\nsamples = 108\nvalue = [107, 1]'),
#  Text(0.07291666666666667, 0.5357142857142857, 'gini = 0.0\nsamples = 94\nvalue = [94, 0]'),
#  Text(0.09375, 0.5357142857142857, 'x[5] <= 23.55\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.08333333333333333, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10416666666666667, 0.4642857142857143, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.125, 0.6071428571428571, 'x[2] <= 22.0\ngini = 0.23\nsamples = 83\nvalue = [72, 11]'),
#  Text(0.11458333333333333, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13541666666666666, 0.5357142857142857, 'x[5] <= 38.3\ngini = 0.214\nsamples = 82\nvalue = [72, 10]'),
#  Text(0.125, 0.4642857142857143, 'x[3] <= 40.5\ngini = 0.274\nsamples = 61\nvalue = [51, 10]'),
#  Text(0.09375, 0.39285714285714285, 'x[5] <= 33.65\ngini = 0.222\nsamples = 55\nvalue = [48.0, 7.0]'),
#  Text(0.0625, 0.32142857142857145, 'x[5] <= 33.45\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.052083333333333336, 0.25, 'x[6] <= 0.284\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.03125, 0.17857142857142858, 'x[7] <= 24.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.020833333333333332, 0.10714285714285714, 'x[2] <= 69.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.010416666666666666, 0.03571428571428571, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03125, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.041666666666666664, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07291666666666667, 0.17857142857142858, 'x[7] <= 27.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.0625, 0.10714285714285714, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.08333333333333333, 0.10714285714285714, 'x[3] <= 21.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07291666666666667, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09375, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07291666666666667, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.125, 0.32142857142857145, 'x[6] <= 0.664\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(0.10416666666666667, 0.25, 'x[2] <= 83.5\ngini = 0.062\nsamples = 31\nvalue = [30, 1]'),
#  Text(0.09375, 0.17857142857142858, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.11458333333333333, 0.17857142857142858, 'x[2] <= 86.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.10416666666666667, 0.10714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.125, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14583333333333334, 0.25, 'x[6] <= 0.739\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.13541666666666666, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15625, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15625, 0.39285714285714285, 'x[3] <= 44.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.14583333333333334, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16666666666666666, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14583333333333334, 0.4642857142857143, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.125, 0.6785714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13541666666666666, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2421875, 0.8214285714285714, 'x[5] <= 26.35\ngini = 0.45\nsamples = 146\nvalue = [96, 50]'),
#  Text(0.19791666666666666, 0.75, 'x[5] <= 9.65\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.1875, 0.6785714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.20833333333333334, 0.6785714285714286, 'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(0.2864583333333333, 0.75, 'x[6] <= 0.558\ngini = 0.484\nsamples = 117\nvalue = [69, 48]'),
#  Text(0.22916666666666666, 0.6785714285714286, 'x[5] <= 27.7\ngini = 0.417\nsamples = 81\nvalue = [57, 24]'),
#  Text(0.21875, 0.6071428571428571, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.23958333333333334, 0.6071428571428571, 'x[2] <= 73.0\ngini = 0.375\nsamples = 76\nvalue = [57, 19]'),
#  Text(0.19791666666666666, 0.5357142857142857, 'x[3] <= 32.5\ngini = 0.478\nsamples = 33\nvalue = [20, 13]'),
#  Text(0.1875, 0.4642857142857143, 'x[7] <= 30.5\ngini = 0.499\nsamples = 27\nvalue = [14, 13]'),
#  Text(0.17708333333333334, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.19791666666666666, 0.39285714285714285, 'x[6] <= 0.141\ngini = 0.483\nsamples = 22\nvalue = [9, 13]'),
#  Text(0.1875, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20833333333333334, 0.32142857142857145, 'x[1] <= 99.0\ngini = 0.432\nsamples = 19\nvalue = [6, 13]'),
#  Text(0.1875, 0.25, 'x[6] <= 0.333\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.17708333333333334, 0.17857142857142858, 'x[1] <= 81.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16666666666666666, 0.10714285714285714, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1875, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19791666666666666, 0.17857142857142858, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.22916666666666666, 0.25, 'x[0] <= 8.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.21875, 0.17857142857142858, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.23958333333333334, 0.17857142857142858, 'x[2] <= 69.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.22916666666666666, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.25, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.20833333333333334, 0.4642857142857143, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.28125, 0.5357142857142857, 'x[5] <= 40.35\ngini = 0.24\nsamples = 43\nvalue = [37, 6]'),
#  Text(0.2604166666666667, 0.4642857142857143, 'x[0] <= 6.5\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.25, 0.39285714285714285, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(0.2708333333333333, 0.39285714285714285, 'x[7] <= 37.0\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(0.2604166666666667, 0.32142857142857145, 'x[1] <= 96.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2708333333333333, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.28125, 0.32142857142857145, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.3020833333333333, 0.4642857142857143, 'x[2] <= 78.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.2916666666666667, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3125, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.34375, 0.6785714285714286, 'x[1] <= 96.5\ngini = 0.444\nsamples = 36\nvalue = [12, 24]'),
#  Text(0.3229166666666667, 0.6071428571428571, 'x[0] <= 9.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.3125, 0.5357142857142857, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3333333333333333, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3645833333333333, 0.6071428571428571, 'x[3] <= 47.5\ngini = 0.337\nsamples = 28\nvalue = [6, 22]'),
#  Text(0.3541666666666667, 0.5357142857142857, 'x[2] <= 91.0\ngini = 0.26\nsamples = 26\nvalue = [4, 22]'),
#  Text(0.34375, 0.4642857142857143, 'x[4] <= 225.0\ngini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(0.3333333333333333, 0.39285714285714285, 'x[2] <= 69.0\ngini = 0.153\nsamples = 24\nvalue = [2, 22]'),
#  Text(0.3229166666666667, 0.32142857142857145, 'x[2] <= 66.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.3125, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34375, 0.32142857142857145, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.3541666666666667, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3645833333333333, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.375, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6416015625, 0.8928571428571429, 'x[5] <= 29.85\ngini = 0.487\nsamples = 198\nvalue = [83, 115]'),
#  Text(0.4635416666666667, 0.8214285714285714, 'x[1] <= 145.5\ngini = 0.406\nsamples = 53\nvalue = [38, 15]'),
#  Text(0.4375, 0.75, 'x[7] <= 28.5\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.4270833333333333, 0.6785714285714286, 'x[0] <= 2.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.40625, 0.6071428571428571, 'x[5] <= 28.8\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.3958333333333333, 0.5357142857142857, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4166666666666667, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4479166666666667, 0.6071428571428571, 'x[5] <= 24.35\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4375, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4583333333333333, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4479166666666667, 0.6785714285714286, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.4895833333333333, 0.75, 'x[7] <= 27.5\ngini = 0.497\nsamples = 26\nvalue = [14, 12]'),
#  Text(0.4791666666666667, 0.6785714285714286, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5, 0.6785714285714286, 'x[7] <= 59.0\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.4895833333333333, 0.6071428571428571, 'x[2] <= 88.0\ngini = 0.415\nsamples = 17\nvalue = [5, 12]'),
#  Text(0.4791666666666667, 0.5357142857142857, 'x[5] <= 22.15\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.46875, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4895833333333333, 0.4642857142857143, 'x[6] <= 0.755\ngini = 0.245\nsamples = 14\nvalue = [2, 12]'),
#  Text(0.46875, 0.39285714285714285, 'x[2] <= 66.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.4583333333333333, 0.32142857142857145, 'x[5] <= 25.85\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.4479166666666667, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.46875, 0.25, 'x[2] <= 32.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4583333333333333, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4791666666666667, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4791666666666667, 0.32142857142857145, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5104166666666666, 0.39285714285714285, 'x[1] <= 175.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5208333333333334, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5104166666666666, 0.6071428571428571, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8196614583333334, 0.8214285714285714, 'x[1] <= 154.5\ngini = 0.428\nsamples = 145\nvalue = [45, 100]'),
#  Text(0.6940104166666666, 0.75, 'x[7] <= 30.5\ngini = 0.487\nsamples = 81\nvalue = [34, 47]'),
#  Text(0.6067708333333334, 0.6785714285714286, 'x[2] <= 73.0\ngini = 0.484\nsamples = 39\nvalue = [23, 16]'),
#  Text(0.5625, 0.6071428571428571, 'x[6] <= 0.183\ngini = 0.43\nsamples = 16\nvalue = [5, 11]'),
#  Text(0.5520833333333334, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5729166666666666, 0.5357142857142857, 'x[1] <= 148.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.5625, 0.4642857142857143, 'x[1] <= 129.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.5520833333333334, 0.39285714285714285, 'x[7] <= 24.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5416666666666666, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5625, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5729166666666666, 0.39285714285714285, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.5833333333333334, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6510416666666666, 0.6071428571428571, 'x[5] <= 43.4\ngini = 0.34\nsamples = 23\nvalue = [18, 5]'),
#  Text(0.625, 0.5357142857142857, 'x[7] <= 21.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.6041666666666666, 0.4642857142857143, 'x[2] <= 84.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.59375, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6145833333333334, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6458333333333334, 0.4642857142857143, 'x[0] <= 4.5\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.6354166666666666, 0.39285714285714285, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.65625, 0.39285714285714285, 'x[2] <= 77.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6458333333333334, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6770833333333334, 0.5357142857142857, 'x[2] <= 82.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6666666666666666, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6875, 0.4642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.78125, 0.6785714285714286, 'x[6] <= 0.429\ngini = 0.387\nsamples = 42\nvalue = [11, 31]'),
#  Text(0.7395833333333334, 0.6071428571428571, 'x[3] <= 31.0\ngini = 0.498\nsamples = 17\nvalue = [8, 9]'),
#  Text(0.71875, 0.5357142857142857, 'x[6] <= 0.136\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.7083333333333334, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7291666666666666, 0.4642857142857143, 'x[6] <= 0.263\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.71875, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7395833333333334, 0.39285714285714285, 'x[7] <= 37.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7291666666666666, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.32142857142857145, 'x[0] <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7395833333333334, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7604166666666666, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7604166666666666, 0.5357142857142857, 'x[4] <= 44.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.75, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7708333333333334, 0.4642857142857143, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8229166666666666, 0.6071428571428571, 'x[4] <= 333.5\ngini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(0.8125, 0.5357142857142857, 'x[6] <= 1.551\ngini = 0.153\nsamples = 24\nvalue = [2, 22]'),
#  Text(0.7916666666666666, 0.4642857142857143, 'x[2] <= 83.0\ngini = 0.087\nsamples = 22\nvalue = [1, 21]'),
#  Text(0.78125, 0.39285714285714285, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.8020833333333334, 0.39285714285714285, 'x[5] <= 38.35\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7916666666666666, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8125, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8333333333333334, 0.4642857142857143, 'x[3] <= 17.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8229166666666666, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.84375, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.5357142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9453125, 0.75, 'x[4] <= 544.0\ngini = 0.285\nsamples = 64\nvalue = [11, 53]'),
#  Text(0.9114583333333334, 0.6785714285714286, 'x[2] <= 69.0\ngini = 0.231\nsamples = 60\nvalue = [8, 52]'),
#  Text(0.875, 0.6071428571428571, 'x[5] <= 31.75\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.8645833333333334, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8854166666666666, 0.5357142857142857, 'x[7] <= 47.5\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.875, 0.4642857142857143, 'x[2] <= 63.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.8645833333333334, 0.39285714285714285, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.8854166666666666, 0.39285714285714285, 'x[3] <= 27.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.875, 0.32142857142857145, 'x[6] <= 0.203\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8645833333333334, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8854166666666666, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8958333333333334, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8958333333333334, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9479166666666666, 0.6071428571428571, 'x[7] <= 36.5\ngini = 0.162\nsamples = 45\nvalue = [4, 41]'),
#  Text(0.9375, 0.5357142857142857, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.9583333333333334, 0.5357142857142857, 'x[5] <= 45.25\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.9479166666666666, 0.4642857142857143, 'x[6] <= 1.407\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.9375, 0.39285714285714285, 'x[7] <= 39.0\ngini = 0.188\nsamples = 19\nvalue = [2, 17]'),
#  Text(0.9166666666666666, 0.32142857142857145, 'x[4] <= 112.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.90625, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9270833333333334, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9583333333333334, 0.32142857142857145, 'x[0] <= 1.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.9479166666666666, 0.25, 'x[6] <= 0.388\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9375, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9583333333333334, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.96875, 0.25, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.9583333333333334, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.96875, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9791666666666666, 0.6785714285714286, 'x[2] <= 69.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.96875, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9895833333333334, 0.6071428571428571, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %% [markdown]
# <h1>Optimizing Decision Tree Performance</h1>

# %%
clf = DecisionTreeClassifier(criterion = "entropy", max_depth = 3)
clf = clf.fit(X_train, y_train)

# %%
y_pred = clf.predict(X_test)

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7748917748917749

# %%
rcParams['figure.figsize'] = 80, 50
plot_tree(clf)
# Out:
# [Text(0.5, 0.875, 'x[1] <= 127.5\nentropy = 0.918\nsamples = 537\nvalue = [358, 179]'),
#  Text(0.25, 0.625, 'x[7] <= 28.5\nentropy = 0.699\nsamples = 339\nvalue = [275, 64]'),
#  Text(0.125, 0.375, 'x[5] <= 30.95\nentropy = 0.375\nsamples = 193\nvalue = [179.0, 14.0]'),
#  Text(0.0625, 0.125, 'entropy = 0.132\nsamples = 109\nvalue = [107, 2]'),
#  Text(0.1875, 0.125, 'entropy = 0.592\nsamples = 84\nvalue = [72, 12]'),
#  Text(0.375, 0.375, 'x[5] <= 26.35\nentropy = 0.927\nsamples = 146\nvalue = [96, 50]'),
#  Text(0.3125, 0.125, 'entropy = 0.362\nsamples = 29\nvalue = [27, 2]'),
#  Text(0.4375, 0.125, 'entropy = 0.977\nsamples = 117\nvalue = [69, 48]'),
#  Text(0.75, 0.625, 'x[5] <= 29.85\nentropy = 0.981\nsamples = 198\nvalue = [83, 115]'),
#  Text(0.625, 0.375, 'x[1] <= 145.5\nentropy = 0.86\nsamples = 53\nvalue = [38, 15]'),
#  Text(0.5625, 0.125, 'entropy = 0.503\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.6875, 0.125, 'entropy = 0.996\nsamples = 26\nvalue = [14, 12]'),
#  Text(0.875, 0.375, 'x[1] <= 165.5\nentropy = 0.894\nsamples = 145\nvalue = [45, 100]'),
#  Text(0.8125, 0.125, 'entropy = 0.967\nsamples = 99\nvalue = [39, 60]'),
#  Text(0.9375, 0.125, 'entropy = 0.559\nsamples = 46\nvalue = [6, 40]')]
