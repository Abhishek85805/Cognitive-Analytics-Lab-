# %%
import os
os.environ["PATH"] += os.pathsep + 'D:/Program Files (x86)/Graphviz2.38/bin/'
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint 
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %%
df = pd.read_csv("bank_cleaned.csv").drop(["response_binary", "Unnamed: 0"], axis=1)

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  day  \
# 0   58    management  married   tertiary      no     2143     yes   no    5
# 1   44    technician   single  secondary      no       29     yes   no    5
# 2   33  entrepreneur  married  secondary      no        2     yes  yes    5
# 3   35    management  married   tertiary      no      231     yes   no    5
# 4   28    management   single   tertiary      no      447     yes  yes    5
#
#   month  duration  campaign  pdays  previous poutcome response
# 0   may      4.35         1     -1         0  unknown       no
# 1   may      2.52         1     -1         0  unknown       no
# 2   may      1.27         1     -1         0  unknown       no
# 3   may      2.32         1     -1         0  unknown       no
# 4   may      3.62         1     -1         0  unknown       no

# %%
df["poutcome"] = df["poutcome"].map({'unknown': 0, 'failure': 0, 'success': 1})
df["loan"] = df["loan"].map({'no': 0, 'yes': 1})
df["housing"] = df["housing"].map({'yes': 1, 'no': 0})
df["default"] = df["default"].map({'yes': 1, 'no': 0})
df.sample(5)
# Out:
#        age          job   marital  education  default  balance  housing  loan  \
# 31032   38   technician  divorced   tertiary        0      304        1     0
# 19411   33   management   married   tertiary        0     1071        0     0
# 18077   45       admin.   married  secondary        0      925        0     0
# 38753   39   technician    single   tertiary        0       25        1     0
# 23476   31  blue-collar   married  secondary        0      225        1     0
#
#        day month  duration  campaign  pdays  previous  poutcome response
# 31032   20   apr      0.13         2     -1         0         0       no
# 19411   12   aug      1.38         4     -1         0         0       no
# 18077    6   aug      6.77         2     -1         0         0      yes
# 38753   28   dec      5.25         1    210         2         1      yes
# 23476   18   nov      3.93         1     -1         0         0       no

# %%
X = df.drop("response", axis=1)
y = df["response"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2 ,random_state = 40)

# %% [markdown]
# <h1>Encoding</h1>

# %% [markdown]
# <h4>Ordinal Encoding</h4>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df["education"].unique()
# Out:
# array(['tertiary', 'secondary', 'primary'], dtype=object)

# %%
oe = OrdinalEncoder(categories=[["primary", "secondary", "tertiary"]])

# %%
oe.fit_transform(X_train[["education"]])
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        ...,
#        [2.],
#        [1.],
#        [1.]])

# %%
X_train[["education"]] = oe.transform(X_train[["education"]])

# %%
X_test[["education"]] = oe.transform(X_test[["education"]])

# %% [markdown]
# <h4>Label Encoding</h4>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
y_train = le.transform(y_train)

# %%
y_test = le.transform(y_test)

# %% [markdown]
# <h4>Nominal Encoding</h4>

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop = 'first', dtype = np.int32)

# %%
ohe.fit(X_train[['job', 'marital', 'month', ]])
# Out:
# OneHotEncoder(drop='first', dtype=<class 'numpy.int32'>)

# %%
X_train_encoded = ohe.transform(X_train[['job', 'marital', 'month']]).toarray()
X_test_encoded = ohe.transform(X_test[['job', 'marital', 'month']]).toarray()

# %%
X_train.drop(['job', 'marital', 'month'], axis= 1).values
X_test.drop(['job', 'marital', 'month'], axis= 1).values
# Out:
# array([[ 42.,   1.,   0., ...,  -1.,   0.,   0.],
#        [ 39.,   1.,   0., ..., 175.,   5.,   0.],
#        [ 57.,   2.,   0., ...,  -1.,   0.,   0.],
#        ...,
#        [ 41.,   2.,   0., ..., 315.,   4.,   0.],
#        [ 73.,   1.,   0., ...,  -1.,   0.,   0.],
#        [ 35.,   2.,   0., ...,  -1.,   0.,   0.]])

# %%
X_train = np.hstack((X_train.drop(['job', 'marital', 'month'], axis= 1).values, X_train_encoded))
X_test = np.hstack((X_test.drop(['job', 'marital', 'month'], axis= 1).values, X_test_encoded))

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9089239809034153
